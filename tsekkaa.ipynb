# %% [markdown]
# # Syväoppiminen harjoitustyö (max 15 p)

# %%
# Kirjoita tähän tietosi!
student_name = Timo Laakkonen
student_id = AA4598

# %% [markdown]
# Tehtävässä vertaillaan eri koneoppimismenetelmät (kuusi eri menetelmää) samalle datalle.
# Tallennetaan tulokset ja analysoidaan ne.
# Esitetään tuloksia myös visuaalisesti (Ennustetarkkuus, sekaannusmatriisi, ROC-käyrä).
# Lisäksi vertaillaan saatuja tuloksia sekä pohditaan tuloksia sanallisesti.

# %% [markdown]
# ## Aineisto: pyöräilytidot
#
# Tiedostossa [activities.csv] on mittaustietoja pyöräilysuorituksista.
#
#
# ## Tehtävä 6.1
# ### Datan esikäsittely (2 pistettä)
#
# Tutustu aineistoon ja toteuta datan esikäsittely.
# * Esikäsittelyn toteutuksessa kannattaa huomioida, että `male` ja `female` kenttien arvot oltava numeerisia koneoppimisvaiheessa

# %% [markdown]
# ## Tehtävä 6.2
# ### Koulutus- ja testiaineisto (2 pistettä)
#
# Tehdään datan jako opetus- ja testijoukkoon sekä skaalataan numeerinen data.

# %%
## haetaan 2 suurella ja ennustetaan mitä muut suureet ovat aineiston perusteella Machine Learning

y_train=y_train.astype(int)

from sklearn.ensemble import RandomForestClassifier
def rfc(X_train, y_train,X_test,p):
    
    #rfc = RandomForestClassifier(random_state=2258, max_depth=8,n_estimators= 55)
    rfc = RandomForestClassifier()
    rfc.fit(X_train, y_train)
    if p==0:
        return rfc.predict(X_test)
    else:
        return rfc

from sklearn.neighbors import KNeighborsClassifier
def knn(X_train, y_train,X_test,p):
    knn = KNeighborsClassifier(n_neighbors=4) # HUOM parametri
    knn.fit(X_train, y_train)
    if p==0:
        return knn.predict(X_test)
    else:
        return knn

#y_pred=knn(X_train, y_train,X_test,0)    

from sklearn.svm import LinearSVC
def svm(X_train, y_train,X_test,p):
    svm = LinearSVC(max_iter=1000)
    svm.fit(X_train, y_train)
    if p==0:
        return svm.predict(X_test)
    else:
        return svm

#y_pred=svm(X_train, y_train,X_test,0);


#y_pred=rfc(X_train, y_train,X_test,0)
#print("###################################")
#print(y_pred)


from sklearn.metrics import confusion_matrix,accuracy_score,roc_curve,roc_auc_score

def plot_roc_curve(y_test,y_pred,label):    
    fpr, tpr, _ = roc_curve(y_test, y_pred,pos_label=1)
    #auc = round(roc_auc_score(y_test, y_pred), 2)
    auc="xxx"
    plt.plot(fpr,tpr,label=f"{label}, AUC={auc}",linewidth=3)
    plt.legend()

y_test=y_test.astype(int)    
#print(y_test)
#print(X_test)

#print(X_train)
#print("------------------")
#print(y_test)
#print("xxx------------------")
#print(y_pred)
#print("------------------")
#plot_roc_curve(y_test,y_pred,"RandomForest")

#y_pred=svm(X_train, y_train,X_test,0)
#plot_roc_curve(y_test,y_pred,"svm")

# pitää poistaa väärät arvot, mittaus on seonnut kun/jos arvo on yli 170, silloin on ehengenlähtö lähellä 
#print("==================================")
#print(df.loc[[2528]])

# %%
# TODO: Kirjoita toteutuksesi tähän soluun.

# ei voida tehdä täysin luetettavaa yleistävää analyysiä koska muuttuvia ja vaikuttavia tekijöitä on monia/useita
# sääolosuhteista lähtien vireystilaan/energiaan kellonaikaan ja kuinka ikä vaikuttaa HALUAN TODITAA ETTÄ 
# vauhtio on mielestäni pysynyt hyvällä tasolla tosin matkat lyhentyneet TODISTA, filtteröi lyhyet matkat, 
# tosin niita ei 10 vuoden alussa juurikaan ollut vai oliko? 

import pandas as pd
import matplotlib.pyplot as plt
pd.options.display.max_rows = 2000

# HAE POIKKEMAT YMS:
df = pd.read_csv("./data/activities.csv",delimiter=",")

#print(df[:1])

# valitaan pyöräily aktiviteetit
df = df[df['Activity Type'] == 'Ride']

#display(df.isna().sum())

#df['label'] = df['label'].replace({'male':1 ,'female':0})
#df.fillna(0,inplace=True)
############################
# valitaan ensin halutut kentät ja sitten vasta poistetaan rivit joissa NaN riippuen mitä dataa tarkastellaan


#empty=df[df.isin([NaN]).any(axis=1)]
#val=round(len(empty)/len(df)*100,2)
#print(val)
# dropping the rows having NaN values
#df = df.dropna()
 
# To reset the indices
#df = df.reset_index(drop = True)

#rivejä, joissa tyhjiä sarakkeita on 2.29% koko datasta
#print(f'rivejä, joissa tyhjiä sarakkeita on {val}%:a koko datasta')
# joten voidaan poistaa kokonaan aineistosta
#df=df[~df.isin(['?']).any(axis=1)]

# tämä kaikki esikäsittelyä datetime muutokset yms.

# average speed turha koska lasketaan km/h
#display(df)
df=df[['Activity ID','Activity Name','Activity Date','Moving Time','Distance','Average Heart Rate','Max Heart Rate','Max Watts','Average Watts','Calories']]

#df=df=df[['Moving Time','Distance','Average Speed','Average Heart Rate','Max Heart Rate','Max Watts','Average Watts','Calories']]

#print(df)

# muutetaan formaati toiseksi niin on helpompi käsitellä
df['Activity DateTime']=pd.to_datetime(df['Activity Date'])

# lisätään pari kenttää
df['Year'] = df['Activity DateTime'].dt.year
df['Month'] = df['Activity DateTime'].dt.month
df['Week'] = df['Activity DateTime'].dt.week
df['Dayofweek'] = df['Activity DateTime'].dt.isocalendar().week 

df['km/h'] = df['Distance'] / (df['Moving Time'] / 3600)


#print(df['km/h'][:10])
#print(df.columns)


avgHR=df[['Average Heart Rate']]

# aina (melko useasti) ei ole ollut sykkeenmittaus päällä, joten poistetaan keskimääräistä syketasoa laskiessa koko aineistosta
avgHR = avgHR.dropna()
 
# To reset the indices
avgHR = avgHR.reset_index(drop = True)

#print(avgHR.sum().values)
#print(avgHR.shape[0])
#print(avgHR.sum().values/avgHR.shape[0])
#print(avgHR[:100])

maxHR=df[['Max Heart Rate','Average Heart Rate']]

# aina (melko useasti) ei ole ollut sykkeenmittaus päällä, joten poistetaan keskimääräistä syketasoa laskiessa koko aineistosta
maxHR = maxHR.dropna()
 
# To reset the indices
maxHR = maxHR.reset_index(drop = True)
"""
print(maxHR.sum().values)
print(maxHR.shape[0])
print(maxHR.sum().values/maxHR.shape[0])
maxHR=maxHR.sort_values(by=['Max Heart Rate'],ascending=False)
"""
#print(maxHR)

#display(maxHR.loc[(maxHR['Max Heart Rate']==180)])

#print(df[1:2])
#print(df.loc[df.index[0]])


########################################################
# 1 esim. kuinka keskinopeuden käy kun matka pitenee, oletus laskee mutta missä suhteessa
# 2 mikä on arvioitu keskinopeus kun/jos matka on 50
# kuinka ikä vaikuttaa eli vuosi vuodelta alkaa heiketä, jossakin on saturaatiopiste
# sen tiedän, että matkat ovat lyhentyneet radikaalisti mutta perus luontainen nopeus heikentynyt vain hieman, mutta paljonko
# miten tuo voidaan suhteuttaa olisiko est power ratkaisu tuohon???

# TESTATAAN mallia antamalla jonkin olemassa olevan rivin data ja katsomalla antaako se oikean arvon jota halutaan ennustaa

from sklearn.model_selection import train_test_split
#from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix,accuracy_score #,plot_roc_curve

#df=df[['km/h','Activity ID','Activity Date','Moving Time','Distance','Average Speed','Average Heart Rate','Max Heart Rate','Average Watts','Calories']] #'Max Watts','Relative Effort']]
df2=df[['km/h','Activity ID','Activity Date','Moving Time','Distance']] #,'Average Speed']] ##,'Average Watts','Calories']] #'Max Watts','Relative Effort']]
#columns=['Distance','km/h']
#df=df[columns] #,'Average Heart Rate','Max Heart Rate','Max Watts','Average Watts','Calories','Relative Effort']]


### NaN:t pudotetaan vain kun tietyt suureet on käsittwlyssä muuten menee dataa hukkaan tiettyjen suureiden 
df2 = df2.dropna()
df2 = df2.reset_index(drop = True)

print(df2.shape)
#df=df[:10]
#df['Average Speed']=df['Average Speed'].astype(int)
y = df2['Distance']
X = df2.drop('Distance', axis=1)
print(">>>>>>>>>>>>>>>>>>>>>>>>>>")
#print(df2)
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8) #, random_state=1150)

#ss = StandardScaler() # vai minmaxscaler kokiel ja vertaa!!!!
#ss.fit(X_train)
#X_train = ss.transform(X_train)
#X_test = ss.transform(X_test)

#print(columns[1:])
"""
mms = MinMaxScaler().fit(X_train)
X_train = pd.DataFrame(mms.transform(X_train), columns=columns[:1])
X_test = pd.DataFrame(mms.transform(X_test), columns=columns[:1])

print(df)

print(type(X_train))
print(type(y_train))
print(type(X_test))
"""

# tee funktoto kaikista niin on siisitimpää, mahd. luokkakin??


# rekressio ei anna kuvaa tästä päivästä kun koko data on käytössä
# tämä (väärä havainto vaikkin oikea sinäänsä) johtuu siitä että matkat ovat viime vuosina lyhentyneet 
# tästä ei voida tehdä yleistävää regressiota
# näyttää ylöspöin, olin voimissain vuosi xxx
#df=df[10:100]
# näyttää jo alaspäin
#df=df[1000:1100]
#print(df)

# koko matrialli antaa väärän mielikuvan
# voidaan havaita jokunen väärä arvo, joka johtuu jostakin virhepiikistä mittauksessa!!!!!
# näin ollen keskinopeus on väärä, mutta jospa laskisi matka/aika ja vertaisi datassa valmiina olevaan tietoon

columns=['Distance','km/h']
import seaborn as sns
sns.regplot(x = columns[0] , 
                y = columns[1], 
                data = df,scatter_kws={"color": "orange",'s':10}, line_kws={"color": "black"},ci=None)
plt.show()






#columns=['Distance','km/h']




"""
sns.regplot(x = columns[0] , 
                y = columns[1], 
                data = df[1000:1500],scatter_kws={"color": "orange",'s':10}, line_kws={"color": "black"},ci=None)
plt.show()
"""

# edelleenkin virhetulkoksia eli poikkeamia datassa havaittavissa
# otetaan siis tarkasteluun yli 30km/h olevat suoritukset, niitä ei todellisuudessa ole montaa ja
# jos onkin niin hieman yli 30km/h on totta
# syyt virhearvoihin tai paremminkin jotkut ilmisesti nopeustesti tehty lyhyellä matkalla (en muista)

print(df.shape)
# poistetaan poikkeamat
df2=df.loc[~(df['km/h']>33)] ## | (df['Distance']<5)])

#print(df2)
print(df2.shape)


sns.regplot(x = columns[0] , 
                y = columns[1], 
                data = df2,scatter_kws={"color": "orange",'s':10}, line_kws={"color": "black"},ci=None)
plt.show()

# jos halutaan ennustaa niin olisi varmaankin koodin eka tsekaata mikä season on ja suhteuttaa tähän dataan
# sillä takuuvarmasti arvot talvella on eri kuin kesällä






print("kokeile tähän regression tuossa alempana")
###########################
#df=df[['km/h','Moving Time','Distance']]
#pp_df = runs[['distance', 'elevation gain', 'km per hour', 'max heart rate', 'calories']]
sns.pairplot(df[['km/h','Moving Time','Distance']]);

###########################
df.hist(bins=50,figsize=(20,15))
###########################
# tähän eri kuukausi vertailu
###########################
# df.corr()['kudos_count'].sort_values(ascending=False)[1:]
# df.corr mutta mihin?
###########################
#sns.heatmap
###########################
# millä funktiolla saadaan meanit yms.
display(df.describe())
# mikä on std, ehkä parempi kaikki mitä halutaanottaa erikseen
display(df['Distance'].mean())
display(df['Distance'].max())
###########################
print("##################")
#display(df)
# Out:
# (2502, 5)
# >>>>>>>>>>>>>>>>>>>>>>>>>>
# (2502, 16)
# (2495, 16)
# kokeile tähän regression tuossa alempana
#         Activity ID   Moving Time     Distance  Average Heart Rate  \
# count  2.502000e+03   2502.000000  2502.000000         1197.000000
# mean   2.277765e+09   3466.615108    24.094776          135.882078
# std    2.316297e+09   1917.987226    13.797216            6.784203
# min    1.287044e+07      4.000000     0.000000           92.451027
# 25%    3.180909e+08   2243.000000    15.060000          131.449768
# 50%    1.361230e+09   3000.000000    20.595000          136.406998
# 75%    4.244012e+09   4219.500000    30.137500          140.832001
# max    8.211470e+09  28800.000000   111.070000          155.792206
#
#        Max Heart Rate  Max Watts  Average Watts     Calories         Year  \
# count     1201.000000        0.0    2465.000000  1846.000000  2502.000000
# mean       150.613655        NaN     273.993570  1021.861437  2016.736611
# ...

# %%
## Tee funktio jota voidaan jatkosssa hyödyntää muutenkin erikseen predic scaatter orange

def linearRegression(df,columns,value):

    X = np.array(df[columns[0]]).reshape(-1, 1)
    y = np.array(df[columns[1]]).reshape(-1, 1)

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

    
    model = LinearRegression()

    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_test)

    sns.set_style('dark')
    plt.figure()
    plt.gcf().set_size_inches(17, 10)
    plt.scatter(X_test, y_test, color ='orange')
    plt.plot(X_test, y_pred, color ='k')
    
    x_pre = [[value]]    
    y_pre = model.predict(x_pre)
    
    plt.plot(x_pre,y_pre, marker='o', c="navy", ms=20,ls='none')

    plt.xlabel(columns[0], size=14)
    plt.ylabel(columns[1], size=14)
    plt.title(f"Matkan pituuden vaikutus keskinopeuteen",size=16)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)

    plt.show()
    return y_pre

columns=['Distance','km/h']
value=20
result=linearRegression(df2,columns,value)
print(f'Matka {value} km, arvioitu keskinopeus on {round(result[0][0],2)} km/h')
# Out:
# Matka 20 km, arvioitu keskinopeus on 24.4 km/h

# %%
Tämä ei pidä varmaankaan paikkaansa nyt tänä vuodenaikan eli tavella joten katsotaan seuraavaksi mitä saadaan arvioksi 
kun aineistoksi erotetaan talvikausi.

# %%
#Tehdään testi: Aion pyöräillä tänään 20 km, mikä mahtaa olla arvioitu keskinopeuteni kun teen rutiiinisuorituksen?

# tämä on jossakin muuallakin Tee funktio!!! tai oikeastaan lisätään alkuun
seasons=['Spring','Summer','Autumn','Winter']

df2.loc[(df2["Month"]>=3) & (df2["Month"]<=5), 'Season'] = seasons[0]
df2.loc[(df2["Month"]>=6) & (df2["Month"]<=8), 'Season'] = seasons[1]
df2.loc[(df2["Month"]>=9) & (df2["Month"]<=11), 'Season'] = seasons[2]
df2.loc[(df2["Month"]==1) | (df2["Month"]==2) | (df2["Month"]==12), 'Season'] = seasons[3]


def getSeason(month):
    seasons=['Spring','Summer','Autumn','Winter']
    
    if (month>=3) & (month>=5):
        return seasons[0]
    elif (month>=6) & (month>=8):
        return seasons[1]
    elif (month>=9) & (month>=11):
        return seasons[2]    
    elif (month==12) | (month==1) | (month==2):        
        return seasons[3]
   
season=getSeason(1)

dfForSeason=df2.loc[df2['Season']==season]
display(dfForSeason.shape)

columns=['Distance','km/h']
value=20
result=linearRegression(dfForSeason,columns,value)
print(f'Matka {value} km, arvioitu keskinopeus on {round(result[0][0],2)} km/h (ko. vuodenajan {season} mukainen aineisto)')
# Out:
# (573, 19)
# Matka 20 km, arvioitu keskinopeus on 21.76 km/h (ko. vuodenajan Winter mukainen aineisto)

# %% [markdown]
# Yleisesti ottaen luulisi vauhdin/nopeuden hyytyvän kun matka pitenee, mutta tähän on selitys matkojen pituus on pysynyt tietyssä rangessa jolloin on voinut määrätietoisen tehokkaasti tehdä suoritukset. Oman kokemukseni mukaan tulos ei ollut yllätys sillä usein kiristän vauhtia loppua kohden. Keskinopeus on melko pienllä vaihtelulalueella koko aineot huomioiden.
# Kun tekee ennustuksen pitäisi ohjelman hakea päivämäärän perusteella season ja sen perusteella ennuste tehdään ko. vuodenajan aineiston suhteen.

# %%
#Koneoppimisen menetelmät em. datalla ja ennustamisella: samainen train ja test käy ja kun ei muita suureita niin ei tarvii

## Tee funktio jota voidaan jatkosssa hyödyntää muutenkin erikseen predic scaatter orange
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import StandardScaler

def gnb(df,columns,value):

    X = np.array(df[columns[0]]).reshape(-1, 1)
    y = np.array(df[columns[1]]).reshape(-1, 1)

    #X = df[columns[0]]
    #y = df[columns[1]]
    
    """
    ss = StandardScaler()
    ss.fit(X_train)
    X_train = ss.transform(X_train)
    X_test = ss.transform(X_test)
    """

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

    
    #print("------------")
    #print(X_train)
    #print("------------")
    #print(y_train)
    #print("------------")
    
    #ss = StandardScaler()
    #ss.fit(X_train)
    #X_train = ss.transform(X_train)
    #X_test = ss.transform(X_test)
    
    #model = GaussianNB()
    
    from sklearn.neighbors import KNeighborsClassifier
    #def knn(X_train, y_train,X_test,p):
    model = KNeighborsClassifier(n_neighbors=4) # HUOM parametri
    model.fit(X_train, y_train)
    
    ##return knn.predict(X_test)
    
    
    #model = LinearRegression()
    #model.fit(X_train, y_train)
    

    y_pred = model.predict(X_test)
    
    #y_pred=gnb(X_train, y_train,X_test,0)
    
    #model = LinearRegression()

    #model.fit(X_train, y_train)
    
    #y_pred = model.predict(X_test)

    """
    sns.set_style('dark')
    plt.figure()
    plt.gcf().set_size_inches(17, 10)
    plt.scatter(X_test, y_test, color ='orange')
    plt.plot(X_test, y_pred, color ='k')
    
    x_pre = [[value]]    
    y_pre = model.predict(x_pre)
    
    plt.plot(x_pre,y_pre, marker='o', c="navy", ms=20,ls='none')

    plt.xlabel(columns[0], size=14)
    plt.ylabel(columns[1], size=14)
    plt.title(f"Matkan pituuden vaikutus keskinopeuteen",size=16)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)

    plt.show()
    """    
    return 0 #y_pre

columns=['Distance','km/h']
value=40
result=gnb(df2,columns,value)
print(f'Matka {value} km, arvioitu keskinopeus on {round(result[0][0],2)} km/h')
# Out:
# C:\Users\User\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1740/1184881477.py in <module>
#      82 columns=['Distance','km/h']
#      83 value=40
# ---> 84 result=gnb(df2,columns,value)
#      85 print(f'Matka {value} km, arvioitu keskinopeus on {round(result[0][0],2)} km/h')
#
# ~\AppData\Local\Temp/ipykernel_1740/1184881477.py in gnb(df, columns, value)
#      39     #def knn(X_train, y_train,X_test,p):
#      40     model = KNeighborsClassifier(n_neighbors=4) # HUOM parametri
# ---> 41     model.fit(X_train, y_train)
#      42
#      43     ##return knn.predict(X_test)
#
# ...

# %% [markdown]
# ### Analytiikkaa

# %%
### muitakin suureita on kuin matka!!!! mutta muita ei juurikaan summata välttämättä

import seaborn as sns
import numpy as np
plt.figure()
sns.set_style('dark')

months=df['Month'].unique()
months=np.sort(months)

## nämä ovat siis tietoja yelisesti koko historian ajalta
monthNames = ['January', 'February', 'March', 'April', 'May', 'June', 'July','August', 'September', 'October', 'November', 'December']


years=df['Year'].unique()

distance=[]
for year in years:    
    x=df.loc[df['Year']==year]    
    distance.append(x['Distance'].sum())
    
distance=np.array(distance)
#data = pd.DataFrame(distance,years)

data={'Year':years,'Distance':distance}

data = pd.DataFrame(data)

sns.barplot(x='Year', y='Distance', data=data, hue='Year', ci=None,palette = 'rocket',dodge=False)
plt.gcf().set_size_inches(17, 6)
#plt.legend(loc='upper right')


plt.figure()
    sns.set_style('dark')

#sns.lineplot(x='Year', y='Distance', data=df, hue='Year', ci=None, estimator=np.sum, palette = 'rocket')
#data=df[['Year','Distance']]
#display(data)

print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print(data['Distance'].max())
maxYear=data.loc[data['Distance']==data['Distance'].max()]['Year']
maxYear=maxYear.values[0]

### maksimivuoden tiedot
datax=df.loc[df['Year']==maxYear]    

#print(data)


plt.figure()


distancex=[]
mNx=[]
for month in months:
    x=datax.loc[datax['Month']==month]    
    distancex.append(x['Distance'].sum())    
    mNx.append(monthNames[month-1])
    
distancex=np.array(distancex)
#print(distance)
#print(mN)
print("¤¤¤¤¤¤¤¤¤¤¤¤")
datax={'Month':mNx,'Distance':distancex}
datax = pd.DataFrame(datax)
display(datax)

sns.barplot(data=datax,x='Month', y='Distance', ci=None, color='steelblue',dodge=False)
#sns.barplot(x='Month', y='Distance', data=datax, hue='Month', ci=None, estimator=np.sum, palette = 'rocket',dodge=False)
plt.gcf().set_size_inches(17, 6)





# tuossa jo aikaisemmin oli samaa koodia. ehkä .values jos columnseja ei saa olla!!!
years=df['Year'].unique()
print(years)




distance=[]
for year in years:
    print(year)
    x=df.loc[df['Year']==year]    
    distance.append(x['Distance'].sum())
    
distance=np.array(distance)
data = pd.DataFrame(distance,years)
sns.lineplot(data=data, palette="tab10", linewidth=2.5)
plt.gcf().set_size_inches(17, 6)
plt.legend(loc='upper right')

plt.figure()
dayNames = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday","Sunday"]
dows=df['Dayofweek'].unique()
dows=np.sort(dows)

distance=[]
dowNames=[]
for day in dows:
    print(day)
    x=df.loc[df['Dayofweek']==day]    
    distance.append(x['Distance'].sum())
    dowNames.append(dayNames[day])
distance=np.array(distance)
print(distance)
print(dowNames)

data={'Day':dowNames,'Distance':distance}

data = pd.DataFrame(data) #,columns=['Day','Distance'])

display(data)

# miten saadaan maksimi viikonpäivän summa selville ja mikä ko. viikonpäivä on???
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print(data['Distance'].max())
print(data.loc[data['Distance']==data['Distance'].max()])
#data.columns=[['Day','Distance']]
#print(data)
plt.figure()



#sns.lineplot(data=data, palette="tab10", linewidth=2.5)
sns.barplot(data=data, x='Day', y='Distance', ci=None, palette = 'rocket',dodge=False)
#sns.barplot(x='Year', y='Distance', data=df, hue='Year', ci=None, estimator=np.sum, palette = 'rocket',dodge=False)
plt.gcf().set_size_inches(17, 6)
#plt.legend(loc='upper right')


#df['Dayofweek']

#plt.plot()

# minä kuukauten atulle pyöräiltyä eniten???
# espanjan data sekoittaa paljonkin koska olosuhteet erit nyt kun ei siellä tule käytyä
# seuraavssa kuukausi kohtaiset summat koko hiostorian ajalta (kuukaudessa 11 eli marraskuu on suurin johtuu espanjan 
# matkoista 2012-2015 jolloin oli "paremmat kelit") todista tämä eli ota siajtipaikka mukaan df:ään
plt.figure()
## voishan noi kuukaudetkin nimetä

distance=[]
mN=[]
for month in months:
    print(month)
    x=df.loc[df['Month']==month]    
    distance.append(x['Distance'].sum())    
    mN.append(monthNames[month-1])
    
distance=np.array(distance)
print(distance)
print(mN)
print("¤¤¤¤¤¤¤¤¤¤¤¤")
data={'Month':mN,'Distance':distance}
data = pd.DataFrame(data)
display(data)

sns.barplot(x='Month', y='Distance', data=data, ci=None, color='steelblue',dodge=False)
#sns.barplot(x='Month', y='Distance', data=df, hue='Month', ci=None, estimator=np.sum, palette = 'rocket',dodge=False)
plt.gcf().set_size_inches(17, 6)
#plt.legend(loc='upper right')


#### Seuraavsksi voidaan hakea maksimivuoden maksimikuukausi ottaa näytille ja näyttää ko. kuukauden päiväkohtaiset suorititukset
### miksei myös minimi

# arvattavissa että maanataaisin vähiten ajoja ja lauantaisin eniten
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 8699.27
# ¤¤¤¤¤¤¤¤¤¤¤¤
#         Month  Distance
# 0     January    347.24
# 1    February    315.38
# 2       March    352.74
# 3       April    175.27
# 4         May    555.13
# 5        June    917.85
# 6        July    582.92
# 7      August    823.01
# 8   September    663.74
# 9     October   1525.25
# 10   November   1688.95
# 11   December    751.79
# [2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022]
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# [7039.98 8415.22 8883.92 8609.98 9260.13 9815.01 8260.89]
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
#          Day  Distance
# 0     Monday   7039.98
# 1    Tuesday   8415.22
# 2  Wednesday   8883.92
# 3   Thursday   8609.98
# 4     Friday   9260.13
# 5   Saturday   9815.01
# 6     Sunday   8260.89
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 9815.01
#         Day  Distance
# 5  Saturday   9815.01
# 1
# 2
# ...

# %%
import seaborn as sns
import numpy as np
plt.figure()
sns.set_style('dark')

months=df['Month'].unique()
months=np.sort(months)

## nämä ovat siis tietoja yelisesti koko historian ajalta
monthNames = ['January', 'February', 'March', 'April', 'May', 'June', 'July','August', 'September', 'October', 'November', 'December']


years=df['Year'].unique()

distance=[]
for year in years:    
    x=df.loc[df['Year']==year]    
    distance.append(x['Distance'].sum())
    
distance=np.array(distance)
#data = pd.DataFrame(distance,years)

data={'Year':years,'Distance':distance}

data = pd.DataFrame(data)

sns.barplot(x='Year', y='Distance', data=data, hue='Year', ci=None,palette = 'rocket',dodge=False)
plt.gcf().set_size_inches(17, 6)
#plt.legend(loc='upper right')


plt.figure()
sns.set_style('dark')

#sns.lineplot(x='Year', y='Distance', data=df, hue='Year', ci=None, estimator=np.sum, palette = 'rocket')
#data=df[['Year','Distance']]
#display(data)

print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print(data['Distance'].max())
maxYear=data.loc[data['Distance']==data['Distance'].max()]['Year']
maxYear=maxYear.values[0]

### maksimivuoden tiedot
data=df.loc[df['Year']==maxYear]    

#print(data)


plt.figure()


distance=[]
mN=[]
for month in months:
    x=data.loc[data['Month']==month]    
    distance.append(x['Distance'].sum())    
    mN.append(monthNames[month-1])
    
distance=np.array(distance)
#print(distance)
#print(mN)
print("¤¤¤¤¤¤¤¤¤¤¤¤")
data={'Month':mN,'Distance':distance}
data = pd.DataFrame(data)
display(data)

sns.barplot(data=datax,x='Month', y='Distance', ci=None, color='steelblue',dodge=False).set(title=f'{maxYear}')
#sns.barplot(x='Month', y='Distance', data=datax, hue='Month', ci=None, estimator=np.sum, palette = 'rocket',dodge=False)
plt.gcf().set_size_inches(17, 6)
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 8699.27
# ¤¤¤¤¤¤¤¤¤¤¤¤
#         Month  Distance
# 0     January    347.24
# 1    February    315.38
# 2       March    352.74
# 3       April    175.27
# 4         May    555.13
# 5        June    917.85
# 6        July    582.92
# 7      August    823.01
# 8   September    663.74
# 9     October   1525.25
# 10   November   1688.95
# 11   December    751.79

# %%
#print(df2['Grade'])

# %% [markdown]
# #### Kuinka eri vuosina eri kuukausina on suoritettu

# %%
### HUOM pitäis poistaa poikkeavat arvot!!!!! esikäsittely sekä silloin kun tarvitaan jossakin NaN ei voi oistaa heti muuten häviää kaikki

#df[monthname]=monthNames[df['Month']]
### huom aiemmin string_array
df['monthName'] = df['Activity DateTime'].dt.month_name()

sns.set_style('dark')
sns.barplot(x='monthName', y='Distance', data=df, hue='Year', ci=None, estimator=np.sum, palette = 'icefire_r',dodge=True,order =["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]) #.set(title=f'{}')
plt.gcf().set_size_inches(17, 6)
plt.legend(loc='upper center')
#plt.legend(bbox_to_anchor=(1.05, 1), loc='upper right', borderaxespad=0)
;
# Out:
# ''

# %% [markdown]
# ### Koneoppiminen

# %% [markdown]
# Virhemahdollisuus on olemassa
#
#
# Tällainen tulos tuli eräällä ajolla, jolloin LinearSVC-metodi antoi väärän tuloksen
# ```
# DecisionTreeClassifier -> luokka: 5.0 ennustettu: 5.0
# LinearSVC -> luokka: 5.0 ennustettu: 4.0
# knn -> luokka: 5.0 ennustettu: 5.0
# GaussianNB -> luokka: 5.0 ennustettu: 5.0
# RandomForestClassifier -> luokka: 5.0 ennustettu: 5.0
# ```
#
# ### Johdanto
# Pyöräilysuoritukseen vaikutta hyvin moini asia, joista sää on kenties tärkein, lislksi varustus, vireystila yms.
# Stravan maksullinen versio voisi antaa suuremman joukon eri paramtreja/muuttujia/suureita
# ### Loppusanat tms.
# Luokitus voisi olla moniputkaisempi ja monia suureita yhdistävä joista voisi laskea vaikka keskiarvo pisteytyksen kokonai gradeksi.

# %%
#Oma luokitus: otetaanko season huomioon
#km/h Distance avgHR  'Calories','Activity Name','Average Watts'
## kokeeksi tehty karkea jako Calories arvojen perusteella
## vois tosin tehdä yhdistelmän monen suureen ja niiden välisten vaikutusten suhteen mutta tämä näin
## ajatuksen tasolla
### kouluarvosanoilla 0-5

### ei ole sama millä metodilla tehdään luokitust ja ennustuksia
### verrataan mikä on paras luokitusmetodi ko. datalle

def dropNanRowByColumn(df,column):

    rowsToDrop = df.loc[(df[column].isnull())].index
    df.drop(rowsToDrop,inplace=True) 


dropNanRowByColumn(df2,"Calories")    
    
    
#print(df2.columns)
#df2['Calories'].max()


#print(df2['Calories'].min())


#calories=df2.loc[(df2['Calories']>mean+2500)]

#print(calories[:2])
#print(len(calories))

# tämä tulee alkuun elilisättän uusi kenttä luokalle

# luokitus voisi olla monimutkaisempi, jolloin keskinöiset riippuvuus suhtee tilanteesta riippuen tulisi 
# huomioiuksi mutta

def doClassification(df):
    
    mean=df['Calories'].mean()
        
    df.loc[(df['Calories']>mean+2500),'Grade'] = 5
    
    df.loc[(df['Calories']<=mean+2500) & (df2['Calories']>mean+1000),'Grade'] = 4
    
    df.loc[(df['Calories']<=mean+1000) & (df2['Calories']>mean),'Grade'] = 3
    
    df.loc[(df['Calories']<=mean) & (df2['Calories']>mean-300),'Grade'] = 2
    
    df.loc[(df['Calories']<=mean-300) & (df2['Calories']>mean-600),'Grade'] = 1

    df.loc[(df['Calories']<mean-600),'Grade'] = 0
    
doClassification(df2)


#df2=df[['km/h','Activity ID','Activity Date','Moving Time','Distance']] #,'Average Speed']] ##,'Average Watts','Calories']] #'Max Watts','Relative Effort']]

from sklearn.preprocessing import StandardScaler
#from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix,accuracy_score


df3=df2[['km/h','Moving Time','Distance','Average Watts','Calories','Grade']]
#df3=df2[['Calories','Grade']]

df3.dropna() #inplace=True)

#print(df3.columns)    
#X=df.drop(['actual_productivity','class'], axis=1)

### HUOM poistettu myös luokitteluun 0-5 perustunut kenttä Calories, tällöin vissiin tapahtuu oppimista
### eli 
X = df3.drop(['Grade','Calories'], axis=1)
#X=X.drop('Calories', axis=1)
#print(X)
y = df3['Grade']

#print(df3)

#df3=df2
#columnsToDrop = ['Grade','Season','Activity DateTime'], #,'Activity Date']

#for col in columnsToDrop:
#    df3.drop(col, axis=1, inplace=True)
#X=df3

#print(X.columns)


X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25)

ss = StandardScaler()
ss.fit(X_train)
X_train = ss.transform(X_train)
X_test = ss.transform(X_test)


from sklearn.naive_bayes import GaussianNB
def gnb(X_train, y_train,X_test,p):
    gnb = GaussianNB()
    gnb.fit(X_train, y_train)
    if p==0:    
        return gnb.predict(X_test)
    else:
        return gnb

y_pred=gnb(X_train, y_train,X_test,0)

acc = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)
print("Naive/GaussianNB")
print(acc)
print(cm)
print()

from sklearn.neighbors import KNeighborsClassifier
def knn(X_train, y_train,X_test,p):
    knn = KNeighborsClassifier(n_neighbors=4) # HUOM parametri
    knn.fit(X_train, y_train)
    if p==0:
        return knn.predict(X_test)
    else:
        return knn

y_pred=knn(X_train, y_train,X_test,0)

acc = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)
print("KNeighborsClassifier")
print(acc)
print(cm)
print()

from sklearn.svm import LinearSVC
def svm(X_train, y_train,X_test,p):
    svm = LinearSVC(max_iter=1000)
    svm.fit(X_train, y_train)
    if p==0:
        return svm.predict(X_test)
    else:
        return svm

y_pred=svm(X_train, y_train,X_test,0);

acc = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)
print("LinearSVC")
print(acc)
print(cm)
print()

from sklearn.ensemble import RandomForestClassifier
def rfc(X_train, y_train,X_test,p):
    
    rfc = RandomForestClassifier()
    rfc.fit(X_train, y_train)
    if p==0:
        return rfc.predict(X_test)
    else:
        return rfc

y_pred=rfc(X_train, y_train,X_test,0)

acc = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)
print("RandomForestClassifier")
print(acc)
print(cm)
print()

from sklearn.tree import DecisionTreeClassifier
def dtc(X_train, y_train,X_test,p):
    dtc = DecisionTreeClassifier()    
    dtc.fit(X_train, y_train) 
    if p==0:
        return dtc.predict(X_test)
    else:
        return dtc

y_pred=dtc(X_train, y_train,X_test,0)

acc = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)
print('DecisionTreeClassifier')
print(acc)
print(cm)
print()

def test(luokka,item):    
    item=ss.transform(item)
    print()
    y_pred=dtc(X_train, y_train,item,0)[0]
    if luokka!="":
        print(f'DecisionTreeClassifier -> luokka: {luokka} ennustettu: {y_pred}')
    else:
        print(f'DecisionTreeClassifier -> ennustettu: {y_pred}')
    y_pred=svm(X_train, y_train,item,0)[0]
    if luokka!="":
        print(f'LinearSVC -> luokka: {luokka} ennustettu: {y_pred}')
    else:
        print(f'LinearSVC -> ennustettu: {y_pred}')
    
    y_pred=knn(X_train, y_train,item,0)[0]
    if luokka!="":
        print(f'knn -> luokka: {luokka} ennustettu: {y_pred}')
    else:
        print(f'knn -> ennustettu: {y_pred}')
        
    y_pred=gnb(X_train, y_train,item,0)[0]
    
    if luokka!="":
        print(f'GaussianNB -> luokka: {luokka} ennustettu: {y_pred}')
    else:
        print(f'GaussianNB -> ennustettu: {y_pred}')
        
    y_pred=rfc(X_train, y_train,item,0)[0]
    if luokka!="":
        print(f'RandomForestClassifier -> luokka: {luokka} ennustettu: {y_pred}')
    else:
        print(f'RandomForestClassifier -> ennustettu: {y_pred}')

#item=df.loc[[2]]
#item=df3.loc[[100]]
#item=df.loc[[135]]
#X = df3.drop(['Grade','Calories'], axis=1)
item=df3.loc[756:756]
print(item)
#item=item.drop(['Calories'], axis=1)
#item['Distance']=20
#print(item)
#luokka=item['Grade'].values[0]
#item.drop(['Grade'], axis=1,inplace=True)   
#test(luokka,item)    




luokka=item['Grade'].values[0]
item.drop(['Grade','Calories'], axis=1,inplace=True)   
print(item)
test(luokka,item)

# Muokataan hieman dataa ja katsotaan tulos
#    km/h  Moving Time  Distance  Average Watts
# 22.819998      17522.0    111.07     262.348999

item['Distance']=55
item['km/h']=55/(7522/3600)
# Average Watts teho pidetään samana 
test("",item)


item['Distance']=55
item['km/h']=55/(12522/3600)
item['Average Watts']=100
test("",item)



### 
# voisiko tehdä yhteenvedon montako kutakin arvosanaa on aineistossa!!!!
# Out:
# Naive/GaussianNB
# 0.7678958785249458
# [[ 35   7   0   0   0   0]
#  [  5 105  18   1   0   0]
#  [  0  24  93   9   0   0]
#  [  0   0  32  87   9   0]
#  [  0   0   0   2  32   0]
#  [  0   0   0   0   0   2]]
#
# KNeighborsClassifier
# 0.7678958785249458
# [[ 33   9   0   0   0   0]
#  [ 10 101  15   3   0   0]
#  [  1  29  84  12   0   0]
#  [  0   2  21 102   3   0]
#  [  0   0   0   2  32   0]
#  [  0   0   0   0   0   2]]
#
# LinearSVC
# 0.7006507592190889
# [[ 19  23   0   0   0   0]
#  [  0 115  13   1   0   0]
#  [  0  40  72  14   0   0]
#  [  0   0  34  94   0   0]
#  [  0   0   0  11  23   0]
#  [  0   0   0   0   2   0]]
#
# RandomForestClassifier
# 0.8091106290672451
# [[ 34   8   0   0   0   0]
#  [  6 100  21   2   0   0]
#  [  0  20  92  14   0   0]
#  [  0   0  12 113   3   0]
#  [  0   0   0   2  32   0]
#  [  0   0   0   0   0   2]]
#
# DecisionTreeClassifier
# 0.7462039045553145
# [[ 31  11   0   0   0   0]
#  [  8  96  24   1   0   0]
# ...

# %% [markdown]
# ### Syväoppiminen (yksinkertainen)
# https://ttc8060.pages.labranet.jamk.fi/syvaoppiminen-materiaalit/README-exercises/
# https://student.labranet.jamk.fi/~pelju/dl/ratkaisut_s22/osa2_ratkaisut.html
# https://github.com/mocchicone/Strava-Fitness-Analysis/blob/master/machine_learning/Classification/ML_DeepLearning_AC.ipynb

# %% [markdown]
# ## Tehtävä 6.3
# ### Mallien rakentaminen (6 pistettä)
#
# Ajetaan eri oppimismenetelmät samalle datalle ja tallennetaan tulokset.
# Tässä tehtävässä käytetään seuraavia menetelmiä:
# 1. Päätöspuu
# 2. Tukivektorikone eli SVM
# 3. k lähintä naapuria eli kNN
# 4. Naiivi Nayes Bayes
# 5. Satunnaismetsä eli RandomForest
# 6. PCA - osa 6 esimerkin aihe
#
# Laske kaikissa menetelmissä luokittelutuloksien **tarkkuus** ja **sekaannusmatriisi**.

# %% [markdown]
# ## Tehtävä 6.4
# ### Tulosten analysointi ja käsittely (5 p)
#
# * Verrataan eri menetelmistä saatuja tuloksia toisiinsa
# * Pyri myös hakemaan keskeiset piirteet
#    * Piirrä jokin soveltuva kuvio kahden tärkeimmän selittävän muuttujan avulla
# * Piirrä myös ROC - käyrät eri menetelmiä käytettäessä ja vertaa, miten eri koneoppimismenetelmissä etenee.
# * Sanallinen pohdinta: Miten kehittäisit tai parantaiset oppimistuloksia?
#
# #### Vastaus: Tulosten tulkinta
#
# * TODO: TULOSTEN SANALLISTA TULKINTAA VASTATEN KYSYMYKSIIN, JOITA TEHTÄVÄSSÄ ESITETTY
# * TODO: MUUTAKIN SAA TÄHÄN KOMMENTOIDA TEHTÄVÄÄN LIITTYEN.

# %% [markdown]
# #### Yleisesti
# Eräät menetelmät ovat melko selkeästi parhaimpia ja mielestäni optimoitu tämän tehtävän datan suhteen riittävään tarkkuuteen/ennustettavuuteen, joten optimointiin sen enempää ei kannattane käyttää aikaa. Se, että käyttääkö useampaa menetelmää yhdessä ja niiden tulosten perusteella määrittää keskiarvoisen tuloksen voi olla joissakin tapauksissa varsinkin ei aikakriittisissä (ei paljoa analysoitavaa) kokeilun arvoinen, tosin tällöin selkeästi heikoimmat menetelmät on syytä jättää huomioitta. Koska on useampi mistä valita niin GaussianNB ja PCA & LogisticRegression voidaan jatkon kannalta hylätä tämän datan ja käyttötarkoituksen suhteen.
# Satunnaismetsä oli tässä tapauksessa "hiuksen hienosti" paras menetelmä.
# Myös kNN, tukivektorikone, päätöspuut menetelmät olivat hyviä eli käypäisiä tähän tehtävään.

# %% [markdown]
# ## Menetelmien optimoinnista
# Yleisesti ottaen optimointi on yritystä/ereyhdystä hieman logiikkaa ja onneakin.
# Loopissa voidaan kasvattaa tiettyä parametria jollakin arvovälillä ja selvittää miten se vaikuttaa lopputulokseen.
# esim. seuraavassa haetaan max_depth arvoa
# ```
# def getBetterPrecision():
#     max=0
#     for i in range(1,50):
#         regressor = RandomForestClassifier(random_state=2083, max_depth=i,n_estimators= 69)
#         regressor.fit(X_train, y_train)
#         y_pred = regressor.predict(X_test)
#         cr = accuracy_score(y_test, y_pred)
#         if cr>max:
#             max=cr
#             rs=i
#     return [max,rs]
#
# result=getBetterPrecision()
# print(f'cr={result[0]} max_dept= {result[1]}')
# ```
#
# `cr=0.9889589905362776 max_dept= 11`
#
#
# Mutta tällöin parametrien yhteisvaikutus lopputulokseen on arvailua ja silloin vaaditaan järeämpiä aseita.
#
#
# Esimerkiksi käyttämällä Scikit-Learnin RandomizedSearchCV-menetelmää voidaan muodostaa suuri/haluttu määrä arvoyhdistelmiä ja nähdä niiden yhteisvaikutus lopputulokseen.
# https://towardsdatascience.com/hyperparameter-tuning-the-random-forest-in-python-using-scikit-learn-28d2aa77dd74
#
#
# ##### GaussianNB
# Menetelmää GaussianNB on melko vaikea tai jopa mahdoton tuunata/optimoida tällä "lyhyellä oppimäärällä".
# ```
# from sklearn.naive_bayes import GaussianNB
# model = GaussianNB()
# print(model.get_params())
#
# {'priors': None, 'var_smoothing': 1e-09}
# ```
# mallista/menetelmästä ei saada feature_importances_ arvoja koska se ei sisällä ko. attribuutti
# ```
#
# ```
#
# ##### LogisticRegression
# menetelmää käytettään tässä tehtävässä PCA:n yhteydessä
#
# mallista/menetelmästä ei saada feature_importances_ arvoja koska se ei sisällä ko. attribuuttia
# ```
# AttributeError: 'LogisticRegression' object has no attribute 'feature_importances_
# ```
# Myös viritys vaatisi parempaa perehtymistä.
#
#
# ##### Mielipide
# Ensinnäkin on useita menetelmiä mistä valita, voisi jo päätellä kun oletusparametreilla ajetaan mikä malli ei kelpaa oletusarvoisesti riittävän hyvin ko. datan analysointiin.
# On olemassa monia algoritmeja ja menetelmiä mallien optimointiin.
# Optimointi vie paljon aikaa jos aletaan viilaamaan, mitä monimutkaisempi algoritmi ja datamäärä onsuuri niin suurta laskentatehoa tarvitaan virittämiseen.
# Joskus/usein lisävaikutus on niin pieni, että olisi parempi käyttää aikaa tärkeämpään tekemiseen.
# Tämä mielipide on muodostettu yleisellä tasolla sekä kirjoittajan lyhyellä oppimäärällä aiheesta.

# %% [markdown]
# #### Selittävä muuttuja
# meanfun-arvo on kaikkia menetelmiä käytettäessä se hyvin vallitseva lukuarvo ennustettavuuden suhteen.
# scatter-kaaviosta meanfun-arvoihin liittyen voidaan päätellä, että keskimääräisesti miesäänet sijoittuvat asteikon alapäähän ja naisäänet yläpäähän (tämä siis selkeästi nähtävissä parhaiten sopivia menetelmiä käytettäessä).
# Villi veikkaus, että kyse on äänenkorkeudesta, yleisesti ottaen miehellä matalampi ja naisilla korkeampi ääni.
#
# ps.
# koska muiden muuttujien prosentuaalinen osuus/vaikutus oli niin pieni jätin tehtävän määrittelyssä mainitun toisen parametrin pois kokonaan.

# %% [markdown]
# PCA & LogisticRegression -> luokka: 0 ennustettu: 1
#
# huomataan, että jo lähtökohtaisesti heikoimmalla menetelmällä saatiin sattumanvaraisella "pistokokeella" väärä tulos,
# ko. menetelmän virhemarginaali on melko suuri eli menee lottoamiseksi.
